# %%
from imagenet import ImageNet

# %%
dataset_path = "/scratch_shared/primmere/ILSVRC/Data/CLS-LOC"

# %%
imagenet = ImageNet(dataset_path, 1)
test = imagenet.get_train_set()

# %%
test
# Out:
# Dataset ImageNetDataset
#     Number of datapoints: 259751
#     Root location: /scratch_shared/primmere/ILSVRC/Data/CLS-LOC/train
#     Compose(
#     Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
